# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from boyden_photometry_functions import *

# %%
X = [1720.263,1919.5525,2031.4879,2280.694,2574.5225,2275.4004,2227.7526,2197.8772,2121.4891,2212.2483,2244.3912,2332.501,2368.4263,2429.3093,2461.8317,2574.5225,2429.6872,2429.6872,2476.2005,2498.8903,2502.2933,2507.2095,2510.2346]
x = np.array(X)
Y = [2273.8037,2309.8952,2327.5624,2372.7407,2423.4722,2570.8729,2503.2305,2458.8086,2351.2874,2574.1543,2571.6302,2566.0773,2563.5532,2547.3996,2554.4667,2423.4722,2522.6646,2522.6646,1995.4056,1735.6883,1675.3652,1632.2052,1594.0931]
y = np.array(Y)

# %%
X1 = [1724.2719,1920.1195,1815.4827,2427.1541,2545.5934,2392.4006,2548.1265,2648.1873,2451.3922]
x1 = np.array(X1)
Y1 = [2276.0248,2311.0815,2179.6838,2538.7171,2082.9876,2002.1952,1607.243,1532.4828,1506.1326]
y1 = np.array(Y1)

# %%
x_ref = 2243.46
y_ref = 2449.58

# %%
plt.figure(figsize = (10,7),dpi = 100)
# plt.plot(x - x_ref,y - y_ref,'o', mec = 'k', color = 'pink')
plt.plot(x1-x_ref,y1 - y_ref,'o', mec = 'k')
plt.plot(0,0,'x',mec = 'k', markersize = 15)

# log(M/Mo)<5
plt.plot(x[18] - x_ref,y[18] - y_ref,'^', mec = 'k',color = 'red')
plt.plot(x[20] - x_ref,y[20] - y_ref,'^', mec = 'k',color = 'red')
plt.plot(x[22] - x_ref,y[22] - y_ref,'^', mec = 'k',color = 'red',label = r'$ log(\frac{M}{M_{\odot}}) <5.0$')

# 5<log(M/Mo)<=6
plt.plot(x[5] - x_ref,y[5] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[6] - x_ref,y[6] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[8] - x_ref,y[8] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[10] - x_ref,y[10] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[11] - x_ref,y[11] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[19] - x_ref,y[19] - y_ref,'s', mec = 'k',color = 'lightblue',label = r'$5.0 < log(\frac{M}{M_{\odot}}) \leq 6.0$')

# 6<log(M/Mo)<=7
plt.plot(x[0] - x_ref,y[0] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[2] - x_ref,y[2] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[4] - x_ref,y[4] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[9] - x_ref,y[9] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[12:17] - x_ref,y[12:17] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[21] - x_ref,y[21] - y_ref,'*', mec = 'k',color = 'yellow',label = r'$6.0 < log(\frac{M}{M_{\odot}}) \leq 7.0$')

#log(M/Mo)>=7
plt.plot(x[1] - x_ref,y[1] - y_ref,'H', mec = 'k',color = 'limegreen')
plt.plot(x[3] - x_ref,y[3] - y_ref,'H', mec = 'k',color = 'limegreen')
plt.plot(x[7] - x_ref,y[7] - y_ref,'H', mec = 'k',color = 'limegreen',label = r'$log(\frac{M}{M_{\odot}}) > 7.0$')

plt.xlabel('$X - X_{ref}$ ', font = 'Times New Roman', size = 15)
plt.ylabel('$Y - Y_{ref}$', font = 'Times New Roman', size = 15)

plt.title('Spatial Distribution of Mass', font = 'Times New Roman', size = 20)
leg = plt.legend(loc='lower left',frameon = False)
plt.show()

# %%
plt.figure(figsize = (10,7),dpi = 100)
plt.plot(x - x_ref,y - y_ref,'o', mec = 'k', color = 'black')
plt.plot(x1-x_ref,y1 - y_ref,'o', mec = 'k')
plt.plot(0,0,'x',mec = 'k', markersize = 15)

# t < 5 Myr
plt.plot(x[11] - x_ref,y[11] - y_ref,'^', mec = 'k',color = 'red')
plt.plot(x[19] - x_ref,y[19] - y_ref,'^', mec = 'k',color = 'red',label = r'$ \tau <5 Myr$')

# 5< t <= 10
plt.plot(x[0:3] - x_ref,y[0:3] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[4:7] - x_ref,y[4:7] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[9:11] - x_ref,y[9:11] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[12:19] - x_ref,y[12:19] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[20] - x_ref,y[20] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[22] - x_ref,y[22] - y_ref,'s', mec = 'k',color = 'lightblue',label = r'$5< \tau \leq 10 Myr$')


# 10< t<= 15 Myr
plt.plot(x[8] - x_ref,y[8] - y_ref,'*', mec = 'k',color = 'yellow',label = r'$10 \tau \leq 15 Myr$')

#20< t <= 60 Myr
plt.plot(x[7] - x_ref,y[7] - y_ref,'H', mec = 'k',color = 'limegreen')
plt.plot(x[21] - x_ref,y[21] - y_ref,'H', mec = 'k',color = 'limegreen',label = r'$20 \tau \leq 60 Myr$')

# t > 60
plt.plot(x[3] - x_ref,y[3] - y_ref,'X', mec = 'k',color = 'pink',label = r'$ \tau > 60 Myr$')

plt.xlabel('$X - X_{ref}$ ', font = 'Times New Roman', size = 15)
plt.ylabel('$Y - Y_{ref}$', font = 'Times New Roman', size = 15)

plt.title('Spatial Distribution of Age', font = 'Times New Roman', size = 20)
leg = plt.legend(loc='lower left',frameon = False)
plt.show()

# %%
plt.figure(figsize = (10,7),dpi = 90)
# plt.plot(x - x_ref,y - y_ref,'o', mec = 'k', color = 'black')
plt.plot(x1-x_ref,y1 - y_ref,'o', mec = 'k')
plt.plot(0,0,'x',mec = 'k', markersize = 15)

# Av = 0
plt.plot(x[10] - x_ref,y[10] - y_ref,'^', mec = 'k',color = 'red')
plt.plot(x[18] - x_ref,y[18] - y_ref,'^', mec = 'k',color = 'red', label = r'$A_{v} = 0$')

# Av = 0.25
plt.plot(x[0] - x_ref,y[0] - y_ref,'s', mec = 'k',color = 'lightblue')
plt.plot(x[21] - x_ref,y[21] - y_ref,'s', mec = 'k',color = 'lightblue', label = r'$A_{v} = 0.25$')


# Av = 0.5
plt.plot(x[5] - x_ref,y[5] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[6] - x_ref,y[6] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[11] - x_ref,y[11] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[12] - x_ref,y[12] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[16] - x_ref,y[16] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[20] - x_ref,y[20] - y_ref,'*', mec = 'k',color = 'yellow')
plt.plot(x[22] - x_ref,y[22] - y_ref,'*', mec = 'k',color = 'yellow', label = r'$A_{v} = 0.5$')

# Av = 0.75
plt.plot(x[2] - x_ref,y[2] - y_ref,'H', mec = 'k',color = 'limegreen')
plt.plot(x[9] - x_ref,y[9] - y_ref,'H', mec = 'k',color = 'limegreen')
plt.plot(x[13] - x_ref,y[13] - y_ref,'H', mec = 'k',color = 'limegreen', label = r'$A_{v} = 0.75$')


# Av = 1
plt.plot(x[8] - x_ref,y[8] - y_ref,'X', mec = 'k',color = 'pink')
plt.plot(x[17] - x_ref,y[17] - y_ref,'X', mec = 'k',color = 'pink', label = r'$A_{v} = 1$')

# Av =1.25
plt.plot(x[14] - x_ref,y[14] - y_ref,'d', mec = 'k',color = 'navy', label = r'$A_{v} = 1.25$')

# Av = 1.5
plt.plot(x[1] - x_ref,y[1] - y_ref,'P', mec = 'k',color = 'snow')
plt.plot(x[3] - x_ref,y[3] - y_ref,'P', mec = 'k',color = 'snow', label = r'$A_{v} = 1.5$')


# Av = 1.75
plt.plot(x[19] - x_ref,y[19] - y_ref,'D', mec = 'k',color = 'orange', label = r'$A_{v} = 1.75$')

# Av =2.25
plt.plot(x[4] - x_ref,y[4] - y_ref,'.', mec = 'k',color = 'hotpink')
plt.plot(x[7] - x_ref,y[7] - y_ref,'.', mec = 'k',color = 'hotpink')
plt.plot(x[15] - x_ref,y[15] - y_ref,'.', mec = 'k',color = 'hotpink', label = r'$A_{v} = 2.25$')

plt.xlabel('$X - X_{ref}$ ', font = 'Times New Roman', size = 15)
plt.ylabel('$Y - Y_{ref}$', font = 'Times New Roman', size = 15)

plt.title('Spatial Distribution of Extinction', font = 'Times New Roman', size = 20)
leg = plt.legend(loc='lower left',frameon = False)
plt.show()
